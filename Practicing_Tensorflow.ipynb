# %% [markdown]
# <a href="https://colab.research.google.com/github/ankush-003/Learning-ML-Basics/blob/main/Practicing_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# creating a neural network
model = tf.keras.Sequential([
    # keras.Input(shape=(1,)),
    keras.layers.Dense(units=1, input_shape=(1,))
])
model.compile(optimizer="sgd", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
print(xs.shape)
# Out:
# (6,)

# %%
normalize_layer = tf.keras.layers.Normalization(axis=None)
normalize_layer.adapt(xs)
xs_norm = normalize_layer(xs)
print(xs.shape)
# Out:
# (6,)

# %%
model.fit(xs_norm, ys, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 14ms/step - loss: 19.0780
# Epoch 2/200
# 1/1 [==============================] - 0s 13ms/step - loss: 18.3225
# Epoch 3/200
# 1/1 [==============================] - 0s 16ms/step - loss: 17.5969
# Epoch 4/200
# 1/1 [==============================] - 0s 10ms/step - loss: 16.9001
# Epoch 5/200
# 1/1 [==============================] - 0s 10ms/step - loss: 16.2308
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 15.5881
# Epoch 7/200
# 1/1 [==============================] - 0s 10ms/step - loss: 14.9708
# Epoch 8/200
# 1/1 [==============================] - 0s 11ms/step - loss: 14.3780
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 13.8086
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 13.2618
# Epoch 11/200
# 1/1 [==============================] - 0s 10ms/step - loss: 12.7366
# Epoch 12/200
# ...

# %%
model.predict(normalize_layer([10.0]))
# Out:
# 1/1 [==============================] - 0s 100ms/step
# array([[30.728355]], dtype=float32)
